# %%
import pandas as pd
import matplotlib.pylab as plt
import string                            #导入字符串模块

from itertools import chain

# %%
tab1 = "./hair_dryer.tsv"

df = pd.read_csv(tab1, sep='\t', header=0)

# %%
df = df[~(df['vine'].str.contains("N") & df['verified_purchase'].str.contains("N"))]

# %%
df = df[(df['total_votes'] > 0) & (df['helpful_votes'] > 0)]

# %%
df = df.groupby('product_parent').filter(lambda x: len(x) > 1)

# %%
df.describe(include="all")
# Out:
#        marketplace   customer_id       review_id  product_id  product_parent  \
# count         2775  2.775000e+03            2775        2775    2.775000e+03
# unique           1           NaN            2775         173             NaN
# top             US           NaN  R1CWR0V8FF34H6  B00132ZG3U             NaN
# freq          2775           NaN               1         152             NaN
# mean           NaN  2.978578e+07             NaN         NaN    4.940635e+08
# std            NaN  1.496295e+07             NaN         NaN    2.866049e+08
# min            NaN  3.219200e+04             NaN         NaN    4.239600e+05
# 25%            NaN  1.604536e+07             NaN         NaN    2.351060e+08
# 50%            NaN  2.949251e+07             NaN         NaN    4.867740e+08
# 75%            NaN  4.386433e+07             NaN         NaN    7.346325e+08
# max            NaN  5.309637e+07             NaN         NaN    9.870215e+08
#
#                                          product_title product_category  \
# count                                             2775             2775
# unique                                             143                1
# top     conair 1875 watt tourmaline ceramic hair dryer           Beauty
# freq                                               152             2775
# mean                                               NaN              NaN
# std                                                NaN              NaN
# min                                                NaN              NaN
# 25%                                                NaN              NaN
# 50%                                                NaN              NaN
# 75%                                                NaN              NaN
# max                                                NaN              NaN
#
#         star_rating  helpful_votes  total_votes  vine verified_purchase  \
# count   2775.000000    2775.000000  2775.000000  2775              2775
# unique          NaN            NaN          NaN     2                 2
# top             NaN            NaN          NaN     N                 Y
# freq            NaN            NaN          NaN  2691              2692
# mean       3.840721       5.580180     6.407928   NaN               NaN
# std        1.459326      22.852115    24.715966   NaN               NaN
# min        1.000000       1.000000     1.000000   NaN               NaN
# 25%        3.000000       1.000000     1.000000   NaN               NaN
# 50%        5.000000       1.000000     2.000000   NaN               NaN
# 75%        5.000000       3.000000     4.000000   NaN               NaN
# max        5.000000     499.000000   575.000000   NaN               NaN
#
#        review_headline      review_body review_date    preprocessed
# count             2775             2775        2775            2775
# unique            2359             2770        1487            2768
# top         Five Stars  None available.    1/3/2015  None available
# freq                93                4           8               4
# mean               NaN              NaN         NaN             NaN
# std                NaN              NaN         NaN             NaN
# min                NaN              NaN         NaN             NaN
# 25%                NaN              NaN         NaN             NaN
# 50%                NaN              NaN         NaN             NaN
# 75%                NaN              NaN         NaN             NaN
# max                NaN              NaN         NaN             NaN

# %%
gp_pp = df.groupby('product_parent')

# # 选特定的一组
# print(gp_pp.get_group(732252283)['star_rating'])

# # 遍历
# for item in gp_pp:
#     print(item[0])
#     print(item[1]['star_rating'])

# gp_pp[['star_rating', 'helpful_votes', 'total_votes']].sum()

gp_pp[['star_rating', 'helpful_votes', 'total_votes']].sum().sort_values(by='helpful_votes',ascending=False)
# Out:
#                 star_rating  helpful_votes  total_votes
# product_parent
# 758099411               597           1662         1943
# 47684938                454            877          923
# 732252283               332            625          677
# 127343313               194            534          579
# 694290590               284            483          508
# ...                     ...            ...          ...
# 168649310                22             10           11
# 791081896                12              8           12
# 54987170                 21              6            6
# 552282721                10              5            7
# 945323010                15              3            4
#
# [123 rows x 3 columns]

# %%
df_pp = gp_pp.get_group(694290590)
star = 5

df = df_pp[df_pp['star_rating'] == star]

# %%
display(df)
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 378            US      9129123  R1E4NGFC7ODLH2  B00005O0MZ       694290590
# 627            US     22475097   RYNBIV19CNV2N  B00005O0MZ       694290590
# 860            US     16818295   RFH2KVRONHNM3  B00005O0MZ       694290590
# 906            US     20222657  R1DZZ0YZP0QSOO  B00005O0MZ       694290590
# 923            US     22574658  R38MGJEA9AZO5X  B00005O0MZ       694290590
# 5051           US     48130474  R3JCS5F5XBJFED  B00005O0MZ       694290590
# 5162           US     28934650   RCVJSXRERAJNS  B00005O0MZ       694290590
# 5185           US     16642384  R14502FBSRCWO1  B00005O0MZ       694290590
# 5262           US     23027656  R2SC6HZ6YCX6QW  B00005O0MZ       694290590
# 5300           US     51848386  R2H0OESG0N61QI  B00005O0MZ       694290590
# 5661           US      2462331  R3L3WFKKGA1WAQ  B00005O0MZ       694290590
# 5683           US     50530418  R3LGI56GGPLP9H  B00005O0MZ       694290590
# 5773           US     14333689  R1FGR8SZW8JG60  B00005O0MZ       694290590
# 5802           US     37328343  R2N3UNCKWTQ7X8  B00005O0MZ       694290590
# 5817           US     16716997  R3GI9FXS6JR0N2  B00005O0MZ       694290590
# 5820           US     44250175  R1QRA8W0AQHK6U  B00005O0MZ       694290590
# 5888           US      3438030  R3VHL6UVB9OO6Q  B00005O0MZ       694290590
# 5901           US     49793187  R1A30MF0FWFC7G  B00005O0MZ       694290590
# 5929           US     23548589  R3MYCLKIL07N72  B00005O0MZ       694290590
# 7100           US     23037303  R3OMT4QTI47HPM  B00005O0MZ       694290590
# 7127           US     51852881  R2GT9HW4K6F0G4  B00005O0MZ       694290590
# 7148           US     44859019  R2DWMAG4IQ70ME  B00005O0MZ       694290590
# 7158           US     16307194  R1A3C6RVSNTZU1  B00005O0MZ       694290590
# 7353           US     31804201  R1J03395QBFKPR  B00005O0MZ       694290590
# 7903           US     47642259  R2SSDBDEW15TEA  B00005O0MZ       694290590
# 8423           US      9952577  R1ITF7VKASA3KF  B00005O0MZ       694290590
# 8450           US     39788086  R1HUWY1KFVJEAZ  B00005O0MZ       694290590
# 8485           US     10066887   RMJ8HIV3XHE3R  B00005O0MZ       694290590
# 8496           US     34935781  R1ZZ12JYUYXG4O  B00005O0MZ       694290590
# 10183          US     15034615  R278LKKLHRQJ6P  B00005O0MZ       694290590
# 10740          US     34371966   RFCV029AD41CO  B00005O0MZ       694290590
# 10980          US     53070250   RSBOL48TXFMJ7  B00005O0MZ       694290590
# 11024          US     11168370  R1R3PH8KIUK63X  B00005O0MZ       694290590
# 11282          US     46946160  R19TXN5I5KLWKY  B00005O0MZ       694290590
# 11328          US     51054656  R29PPENAMEGLTG  B00005O0MZ       694290590
# 11397          US     16086911  R1NDRMC9ADPUOC  B00005O0MZ       694290590
# 11406          US     35647799  R17YDVO1GZ0CVZ  B00005O0MZ       694290590
# 11467          US     37733836  R3GO6L5PWBS0IW  B00005O0MZ       694290590
#
#                                            product_title product_category  \
# 378    conair corp pers care 146np conair ionic condi...           Beauty
# 627    conair corp pers care 146np conair ionic condi...           Beauty
# 860    conair corp pers care 146np conair ionic condi...           Beauty
# 906    conair corp pers care 146np conair ionic condi...           Beauty
# 923    conair corp pers care 146np conair ionic condi...           Beauty
# 5051   conair corp pers care 146np conair ionic condi...           Beauty
# 5162   conair corp pers care 146np conair ionic condi...           Beauty
# 5185   conair corp pers care 146np conair ionic condi...           Beauty
# 5262   conair corp pers care 146np conair ionic condi...           Beauty
# 5300   conair corp pers care 146np conair ionic condi...           Beauty
# 5661   conair corp pers care 146np conair ionic condi...           Beauty
# 5683   conair corp pers care 146np conair ionic condi...           Beauty
# 5773   conair corp pers care 146np conair ionic condi...           Beauty
# 5802   conair corp pers care 146np conair ionic condi...           Beauty
# 5817   conair corp pers care 146np conair ionic condi...           Beauty
# 5820   conair corp pers care 146np conair ionic condi...           Beauty
# 5888   conair corp pers care 146np conair ionic condi...           Beauty
# 5901   conair corp pers care 146np conair ionic condi...           Beauty
# 5929   conair corp pers care 146np conair ionic condi...           Beauty
# 7100   conair corp pers care 146np conair ionic condi...           Beauty
# 7127   conair corp pers care 146np conair ionic condi...           Beauty
# 7148   conair corp pers care 146np conair ionic condi...           Beauty
# 7158   conair corp pers care 146np conair ionic condi...           Beauty
# 7353   conair corp pers care 146np conair ionic condi...           Beauty
# 7903   conair corp pers care 146np conair ionic condi...           Beauty
# 8423   conair corp pers care 146np conair ionic condi...           Beauty
# 8450   conair corp pers care 146np conair ionic condi...           Beauty
# 8485   conair corp pers care 146np conair ionic condi...           Beauty
# 8496   conair corp pers care 146np conair ionic condi...           Beauty
# 10183  conair corp pers care 146np conair ionic condi...           Beauty
# 10740  conair corp pers care 146np conair ionic condi...           Beauty
# 10980  conair corp pers care 146np conair ionic condi...           Beauty
# 11024  conair corp pers care 146np conair ionic condi...           Beauty
# 11282  conair corp pers care 146np conair ionic condi...           Beauty
# 11328  conair corp pers care 146np conair ionic condi...           Beauty
# 11397  conair corp pers care 146np conair ionic condi...           Beauty
# 11406  conair corp pers care 146np conair ionic condi...           Beauty
# 11467  conair corp pers care 146np conair ionic condi...           Beauty
#
#        star_rating  helpful_votes  total_votes vine verified_purchase  \
# 378              5              1            1    N                 Y
# 627              5              1            1    N                 Y
# 860              5              1            1    N                 Y
# 906              5              1            1    N                 Y
# 923              5              1            1    N                 Y
# 5051             5              1            1    N                 Y
# 5162             5              1            1    N                 Y
# 5185             5              1            1    N                 Y
# 5262             5              1            1    N                 Y
# 5300             5              1            1    N                 Y
# 5661             5              1            1    N                 Y
# 5683             5              2            2    N                 Y
# 5773             5              2            2    N                 Y
# 5802             5              1            1    N                 Y
# 5817             5              1            1    N                 Y
# 5820             5              1            1    N                 Y
# 5888             5              1            1    N                 Y
# 5901             5              1            1    N                 Y
# 5929             5              2            2    N                 Y
# 7100             5              1            1    N                 Y
# 7127             5              1            1    N                 Y
# 7148             5              1            1    N                 Y
# 7158             5              1            1    N                 Y
# 7353             5              1            1    N                 Y
# 7903             5              1            1    N                 Y
# 8423             5              1            1    N                 Y
# 8450             5              1            1    N                 Y
# 8485             5              1            1    N                 Y
# 8496             5              1            1    N                 Y
# 10183            5              1            1    N                 Y
# 10740            5              9            9    N                 Y
# 10980            5              2            2    N                 Y
# 11024            5              2            2    N                 Y
# 11282            5             14           15    N                 Y
# 11328            5              2            3    N                 Y
# 11397            5              5            6    N                 Y
# 11406            5              5            5    N                 Y
# 11467            5              4            4    N                 Y
#
#                                          review_headline  \
# 378                      Best hair dryer I've ever used~
# 627                                           Five Stars
# 860                                           Five Stars
# 906                     Solid construction, and powerful
# 923                                     4 years later...
# 5051                                          Five Stars
# 5162                                               Great
# 5185                       I'm glad I made the purchase!
# 5262                                          Fantastic!
# 5300                     Best ten bucks I've ever spent!
# 5661                                          Good price
# 5683                                 What's not to like?
# 5773                                          Hair Dryer
# 5802                                 Awesome hair dryer!
# 5817                                           Very good
# 5820                               Exactly as advertised
# 5888                                         Good value!
# 5901   It's a Hair Dryer.  It Works.  What More Could...
# 5929                       Great price and great product
# 7100                                All you really need.
# 7127                          great price great product!
# 7148                       Light weight and not too loud
# 7158                                     Cool Hair Dryer
# 7353                                        Good product
# 7903                                            love it!
# 8423                                         Works great
# 8450                                           great buy
# 8485                                         Works great
# 8496                                                good
# 10183             This dryer has an ionic on/off switch.
# 10740                            Good working hair dryer
# 10980                             Also warms toes nicely
# 11024                                  So far it's great
# 11282                                 Dries hair quickly
# 11328         ...and I thought the ION feature was hype!
# 11397                                   Great Hair Dryer
# 11406                                 softest hair ever!
# 11467                                  The best dryer!!!
#
#                                              review_body review_date  \
# 378    After my $60+ salon brand hair dryer crapped o...   7/31/2015
# 627                                            great buy   7/12/2015
# 860    Love this dryer.  I specifically chose it beca...   6/18/2015
# 906    We were looking for a good quality, simple hai...   6/15/2015
# 923    I've had this hair dryer for almost 4 years no...   6/13/2015
# 5051                Good bang for the buck.  Works fine.    7/3/2014
# 5162   This is a very simple but great blower.  We ar...   6/17/2014
# 5185   I first used this hair dryer in a hotel after ...   6/14/2014
# 5262   Best price I have seen, plus great quality! Su...   5/31/2014
# 5300   First of all, let's put things in perspective ...   5/25/2014
# 5661   It is a little noisy, but works well with stro...   3/31/2014
# 5683   Reasonably priced, light, works well, you can ...   3/27/2014
# 5773   Use this for my dog.  It has a mild setting th...   3/14/2014
# 5802   Works great! It does exactly what it says & It...   3/11/2014
# 5817   I like it. It's working very well. Like the he...   3/10/2014
# 5820   This hair dryer was perfect for my needs, and ...   3/10/2014
# 5888   Works well so far! I thought I'd give it a try...    3/2/2014
# 5901   Let's face it, I'm a guy.  I use a hair dryer ...    3/1/2014
# 5929   I buy cheap. I don't need anything fancy, just...   2/26/2014
# 7100   I was looking for something nice but quiet. Th...   8/28/2013
# 7127   I like this hair dryer, it comes with a defuse...   8/23/2013
# 7148   Liked it.  The cord is definitely shorter than...   8/19/2013
# 7158   The old hair dryer that my wife and I used was...   8/18/2013
# 7353   We were concerned to begin with because of a p...    7/7/2013
# 7903   so glad I purchased this one, so many options ...   3/28/2013
# 8423   I received this as a gift and love it!  I have...    1/9/2013
# 8450   For the money you can't beat it. Plus it comes...    1/6/2013
# 8485   Great product at a great price. Provides just ...    1/2/2013
# 8496   excellent job very satisfied. not too much mor...    1/1/2013
# 10183  This dryer works like it should.    The dryer ...  10/14/2010
# 10740  I suppose some people are never satisfied. I r...   8/16/2009
# 10980  It's a hairdryer.  It blows cold air over a he...  10/16/2008
# 11024  I bought this for my wife when her old one sta...   7/24/2008
# 11282  With below the shoulder hair, I found this to ...   4/15/2007
# 11328  The initial reason for buying this hair dryer ...   2/19/2007
# 11397  This hair dryer really dose make your hair sof...    3/8/2006
# 11406  I have thick, not coarse, but not silky hair. ...   2/24/2006
# 11467  I love this dryer not only is it QUIET, it rea...   7/13/2002
#
#                                             preprocessed
# 378    After my $ 60+ salon brand hair dryer crap out...
# 627                                            great buy
# 860    Love this dryer I specifically choose it becau...
# 906    We be look for a good quality simple hair drie...
# 923    I ve have this hair dryer for almost 4 year no...
# 5051                   Good bang for the buck Works fine
# 5162   This be a very simple but great blower We be u...
# 5185   I first use this hair dryer in a hotel after t...
# 5262   Best price I have see plus great quality Super...
# 5300   First of all let s put thing in perspective --...
# 5661   It be a little noisy but work well with strong...
# 5683   Reasonably price light work well you can turn ...
# 5773   Use this for my dog It have a mild setting tha...
# 5802   Works great It do exactly what it say & It com...
# 5817   I like it It s work very well Like the heat a ...
# 5820   This hair dryer be perfect for my need and the...
# 5888   Works well so far I think I d give it a try si...
# 5901   Let s face it I m a guy I use a hair dryer abo...
# 5929   I buy cheap I don t need anything fancy just s...
# 7100   I be look for something nice but quiet This is...
# 7127   I like this hair dryer it come with a defuser ...
# 7148   Liked it The cord be definitely short than nor...
# 7158   The old hair dryer that my wife and I use be o...
# 7353   We be concern to begin with because of a post ...
# 7903   so glad I purchase this one so many option out...
# 8423   I receive this as a gift and love it I have na...
# 8450   For the money you can t beat it Plus it come w...
# 8485   Great product at a great price Provides just t...
# 8496   excellent job very satisfy not too much more t...
# 10183  This dryer work like it should The dryer have ...
# 10740  I suppose some people be never satisfy I read ...
# 10980  It s a hairdryer It blow cold air over a heati...
# 11024  I buy this for my wife when her old one start ...
# 11282  With below the shoulder hair I find this to dr...
# 11328  The initial reason for buy this hair dryer be ...
# 11397  This hair dryer really dose make your hair sof...
# 11406  I have thick not coarse but not silky hair I r...
# 11467  I love this dryer not only be it QUIET it real...

# %%
pattern = r"\&\#[0-9]+\;"

df["preprocessed"] = df["review_body"].str.replace(pat=pattern, repl="", regex=True)
# Out:
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import re
import nltk

from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from nltk.corpus import wordnet

#import nltk resources
resources = ["wordnet", "stopwords", "punkt", \
             "averaged_perceptron_tagger", "maxent_treebank_pos_tagger"]

for resource in resources:
    try:
        nltk.data.find("tokenizers/" + resource)
    except LookupError:
        nltk.download(resource)

#create Lemmatizer object
lemma = WordNetLemmatizer()

def lemmatize_word(tagged_token):
    """ Returns lemmatized word given its tag"""
    root = []
    for token in tagged_token:
        tag = token[1][0]
        word = token[0]
        if tag.startswith('J'):
            root.append(lemma.lemmatize(word, wordnet.ADJ))
        elif tag.startswith('V'):
            root.append(lemma.lemmatize(word, wordnet.VERB))
        elif tag.startswith('N'):
            root.append(lemma.lemmatize(word, wordnet.NOUN))
        elif tag.startswith('R'):
            root.append(lemma.lemmatize(word, wordnet.ADV))
        else:          
            root.append(word)
    return root
# Out:
# [nltk_data] Downloading package wordnet to /home/alphonse/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/alphonse/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/alphonse/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /home/alphonse/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!

# %%
def lemmatize_doc(document):
    """ Tags words then returns sentence with lemmatized words"""
    lemmatized_list = []
    tokenized_sent = sent_tokenize(document)
    for sentence in tokenized_sent:
        no_punctuation = re.sub(r"[`'\",.!?()]", " ", sentence)
        tokenized_word = word_tokenize(no_punctuation)
        tagged_token = pos_tag(tokenized_word)
        lemmatized = lemmatize_word(tagged_token)
        lemmatized_list.extend(lemmatized)
    return " ".join(lemmatized_list)

# %%
#apply our functions
df["preprocessed"] = df["preprocessed"].apply(lambda row: lemmatize_doc(row))

print(df["preprocessed"].iloc[4])
# Out:
# I ve have this hair dryer for almost 4 year now and to this day I love it I have dry frizzy Hermione Granger-esqe hair so I need something that wouldn t feel like I m fry it I highly highly recommend it to everyone It come with a diffuser which I only use like once or twice but it s ok I m gon na have this one for awhile I love the sleek design too I don t see it become outdated like those pink and green hair dryer from the 70s or something Thanks scientist at Conair I salute you
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from unicodedata import normalize

remove_accent = lambda text: normalize("NFKD", text).encode("ascii", "ignore").decode("utf-8", "ignore")

df["preprocessed"] = df["preprocessed"].apply(remove_accent)

print(df["preprocessed"].iloc[4])
# Out:
# I ve have this hair dryer for almost 4 year now and to this day I love it I have dry frizzy Hermione Granger-esqe hair so I need something that wouldn t feel like I m fry it I highly highly recommend it to everyone It come with a diffuser which I only use like once or twice but it s ok I m gon na have this one for awhile I love the sleek design too I don t see it become outdated like those pink and green hair dryer from the 70s or something Thanks scientist at Conair I salute you
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
pattern = r"[^\w\s]"

df["preprocessed"] = df["preprocessed"].str.replace(pat=pattern, repl=" ", regex=True)

print(df["preprocessed"].iloc[4])
# Out:
# I ve have this hair dryer for almost 4 year now and to this day I love it I have dry frizzy Hermione Granger esqe hair so I need something that wouldn t feel like I m fry it I highly highly recommend it to everyone It come with a diffuser which I only use like once or twice but it s ok I m gon na have this one for awhile I love the sleek design too I don t see it become outdated like those pink and green hair dryer from the 70s or something Thanks scientist at Conair I salute you
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df["preprocessed"] = df["preprocessed"].str.lower()

print(df["preprocessed"].iloc[4])
# Out:
# i ve have this hair dryer for almost 4 year now and to this day i love it i have dry frizzy hermione granger esqe hair so i need something that wouldn t feel like i m fry it i highly highly recommend it to everyone it come with a diffuser which i only use like once or twice but it s ok i m gon na have this one for awhile i love the sleek design too i don t see it become outdated like those pink and green hair dryer from the 70s or something thanks scientist at conair i salute you
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pattern = r"[\s]+"

df["preprocessed"] = df["preprocessed"].str.replace(pat=pattern, repl=" ", regex=True)

print(df["preprocessed"].iloc[4])
# Out:
# i ve have this hair dryer for almost 4 year now and to this day i love it i have dry frizzy hermione granger esqe hair so i need something that wouldn t feel like i m fry it i highly highly recommend it to everyone it come with a diffuser which i only use like once or twice but it s ok i m gon na have this one for awhile i love the sleek design too i don t see it become outdated like those pink and green hair dryer from the 70s or something thanks scientist at conair i salute you
# /home/alphonse/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
corpora = df["preprocessed"].values
tokenized = [corpus.split(" ") for corpus in corpora]

for review in tokenized:
    while '' in review:
        review.remove('')

text = list(chain(*tokenized))

print(text)
# Out:
# ['after', 'my', '60', 'salon', 'brand', 'hair', 'dryer', 'crap', 'out', 'on', 'me', 'after', 'like', '4', 'month', 'i', 'decide', 'to', 'just', 'look', 'for', 'a', 'hair', 'dryer', 'with', 'a', 'great', 'price', 'i', 'do', 'not', 'even', 'realize', 'that', 'it', 's', 'a', 'conditioning', 'dryer', 'and', 'now', 'my', 'hair', 'never', 'look', 'well', 'my', 'old', 'dryer', 'make', 'my', 'hair', 'look', 'dry', 'and', 'unhealthy', 'and', 'i', 'can', 't', 'believe', 'how', 'much', 'good', 'it', 'look', 'now', 'i', 'love', 'it', 'it', 'doesn', 't', 'get', 'super', 'hot', 'but', 'dry', 'my', 'long', 'thick', 'hair', 'fast', 'and', 'fluffy', 'i', 've', 'have', 'it', 'for', 'a', 'little', 'over', 'a', 'year', 'now', 'and', 'it', 'be', 'still', 'work', 'great', 'great', 'buy', 'love', 'this', 'dryer', 'i', 'specifically', 'choose', 'it', 'because', 'it', 'be', 'not', 'as', 'loud', 'as', 'others', 'we', 'be', 'look', 'for', 'a', 'good', 'quality', 'simple', 'hair', 'drier', 'this', 'one', 'seem', 'to', 'fit', 'the', 'bill', 'br', 'it', 'work', 'well', 'dry', 'hair', 'quickly', 'and', 'seem', 'to', 'help', 'tame', 'the', 'frizzies', 'we', 'have', 'be', 'use', 'it', 'for', 'quite', 'a', 'while', 'now', 'and', 'have', 'have', 'absolutely', 'no', 'issue', 'with', 'it', 'i', 've', 'have', 'this', 'hair', 'dryer', 'for', 'almost', '4', 'year', 'now', 'and', 'to', 'this', 'day', 'i', 'love', 'it', 'i', 'have', 'dry', 'frizzy', 'hermione', 'granger', 'esqe', 'hair', 'so', 'i', 'need', 'something', 'that', 'wouldn', 't', 'feel', 'like', 'i', 'm', 'fry', 'it', 'i', 'highly', 'highly', 'recommend', 'it', 'to', 'everyone', 'it', 'come', 'with', 'a', 'diffuser', 'which', 'i', 'only', 'use', 'like', 'once', 'or', 'twice', 'but', 'it', 's', 'ok', 'i', 'm', 'gon', 'na', 'have', 'this', 'one', 'for', 'awhile', 'i', 'love', 'the', 'sleek', 'design', 'too', 'i', 'don', 't', 'see', 'it', 'become', 'outdated', 'like', 'those', 'pink', 'and', 'green', 'hair', 'dryer', 'from', 'the', '70s', 'or', 'something', 'thanks', 'scientist', 'at', 'conair', 'i', 'salute', 'you', 'good', 'bang', 'for', 'the', 'buck', 'works', 'fine', 'this', 'be', 'a', 'very', 'simple', 'but', 'great', 'blower', 'we', 'be', 'use', 'it', 'daily', 'and', 'be', 'happy', 'with', 'it', 'good', 'product', 'i', 'first', 'use', 'this', 'hair', 'dryer', 'in', 'a', 'hotel', 'after', 'that', 'i', 'have', 'to', 'have', 'one', 'i', 'find', 'it', 'on', 'amazon', 'make', 'the', 'purchase', 'and', 'i', 'be', 'very', 'pleased', 'with', 'my', 'purchase', 'best', 'price', 'i', 'have', 'see', 'plus', 'great', 'quality', 'super', 'quiet', 'not', 'a', 'giant', 'long', 'annoying', 'cord', 'not', 'too', 'short', 'of', 'a', 'cord', 'either', 'love', 'love', 'love', 'the', 'diffuser', 'attachment', 'since', 'i', 'have', 'curly', 'hair', 'attachment', 'stay', 'on', 'really', 'well', 'low', 'and', 'warm', 'do', 'a', 'great', 'job', 'on', 'my', 'thin', 'and', 'super', 'curly', 'hair', 'first', 'of', 'all', 'let', 's', 'put', 'thing', 'in', 'perspective', 'i', 'be', 'not', 'a', 'stylist', 'i', 'don', 't', 'use', 'a', 'blow', 'dryer', 'to', 'style', 'my', 'hair', 'but', 'rather', 'to', 'dry', 'it', 'after', 'shower', 'i', 'have', 'very', 'thin', 'fine', 'hair', 'that', 'dry', 'quickly', 'but', 'easily', 'get', 'frizzy', 'and', 'fly', 'away', 'the', 'hand', 'dryer', 'i', 've', 'have', 'for', 'over', '15', 'year', 'do', 'the', 'job', 'but', 'unless', 'i', 'use', 'a', 'leave', 'in', 'conditioner', 'before', 'dry', 'my', 'hair', 'would', 'often', 'end', 'up', 'look', 'like', 'shredded', 'wheat', 'not', 'attractive', 'br', 'br', 'so', 'when', 'it', 'come', 'time', 'to', 'buy', 'a', 'new', 'dryer', 'i', 'take', 'a', 'look', 'at', 'the', 'ionic', 'one', 'which', 'claim', 'to', 'leave', 'hair', 'soft', 'and', 'silky', 'instead', 'of', 'frizzy', 'and', 'fly', 'away', 'and', 'since', 'this', 'one', 'be', 'so', 'inexpensive', 'i', 'figure', 'i', 'd', 'give', 'it', 'a', 'try', 'br', 'br', 'well', 'it', 's', 'fabulous', 'when', 'dr ...

# %%
POS_tag = nltk.pos_tag(text)

print ("Tokenized Text with POS tags: \n")
print (POS_tag)
# Out:
# Tokenized Text with POS tags:
#
# [('after', 'IN'), ('my', 'PRP$'), ('60', 'CD'), ('salon', 'NN'), ('brand', 'NN'), ('hair', 'NN'), ('dryer', 'NN'), ('crap', 'NN'), ('out', 'IN'), ('on', 'IN'), ('me', 'PRP'), ('after', 'IN'), ('like', 'IN'), ('4', 'CD'), ('month', 'NN'), ('i', 'NN'), ('decide', 'VBP'), ('to', 'TO'), ('just', 'RB'), ('look', 'VB'), ('for', 'IN'), ('a', 'DT'), ('hair', 'NN'), ('dryer', 'NN'), ('with', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('price', 'NN'), ('i', 'NNS'), ('do', 'VBP'), ('not', 'RB'), ('even', 'RB'), ('realize', 'VB'), ('that', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('conditioning', 'NN'), ('dryer', 'NN'), ('and', 'CC'), ('now', 'RB'), ('my', 'PRP$'), ('hair', 'NN'), ('never', 'RB'), ('look', 'VBP'), ('well', 'RB'), ('my', 'PRP$'), ('old', 'JJ'), ('dryer', 'NN'), ('make', 'VB'), ('my', 'PRP$'), ('hair', 'NN'), ('look', 'VB'), ('dry', 'JJ'), ('and', 'CC'), ('unhealthy', 'JJ'), ('and', 'CC'), ('i', 'JJ'), ('can', 'MD'), ('t', 'VB'), ('believe', 'VB'), ('how', 'WRB'), ('much', 'JJ'), ('good', 'JJ'), ('it', 'PRP'), ('look', 'VBP'), ('now', 'RB'), ('i', 'RB'), ('love', 'VBP'), ('it', 'PRP'), ('it', 'PRP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('get', 'VB'), ('super', 'JJ'), ('hot', 'JJ'), ('but', 'CC'), ('dry', 'JJ'), ('my', 'PRP$'), ('long', 'JJ'), ('thick', 'JJ'), ('hair', 'NN'), ('fast', 'RB'), ('and', 'CC'), ('fluffy', 'VB'), ('i', 'NN'), ('ve', 'NNS'), ('have', 'VBP'), ('it', 'PRP'), ('for', 'IN'), ('a', 'DT'), ('little', 'JJ'), ('over', 'RP'), ('a', 'DT'), ('year', 'NN'), ('now', 'RB'), ('and', 'CC'), ('it', 'PRP'), ('be', 'VB'), ('still', 'RB'), ('work', 'VB'), ('great', 'JJ'), ('great', 'JJ'), ('buy', 'NN'), ('love', 'IN'), ('this', 'DT'), ('dryer', 'NN'), ('i', 'VBZ'), ('specifically', 'RB'), ('choose', 'VB'), ('it', 'PRP'), ('because', 'IN'), ('it', 'PRP'), ('be', 'VB'), ('not', 'RB'), ('as', 'RB'), ('loud', 'JJ'), ('as', 'IN'), ('others', 'NNS'), ('we', 'PRP'), ('be', 'VB'), ('look', 'VBN'), ('for', 'IN'), ('a', 'DT'), ('good', 'JJ'), ('quality', 'NN'), ('simple', 'JJ'), ('hair', 'NN'), ('drier', 'RBR'), ('this', 'DT'), ('one', 'CD'), ('seem', 'NN'), ('to', 'TO'), ('fit', 'VB'), ('the', 'DT'), ('bill', 'NN'), ('br', 'VBZ'), ('it', 'PRP'), ('work', 'VB'), ('well', 'RB'), ('dry', 'JJ'), ('hair', 'NN'), ('quickly', 'RB'), ('and', 'CC'), ('seem', 'VB'), ('to', 'TO'), ('help', 'VB'), ('tame', 'VB'), ('the', 'DT'), ('frizzies', 'NNS'), ('we', 'PRP'), ('have', 'VBP'), ('be', 'VB'), ('use', 'VBP'), ('it', 'PRP'), ('for', 'IN'), ('quite', 'RB'), ('a', 'DT'), ('while', 'NN'), ('now', 'RB'), ('and', 'CC'), ('have', 'VBP'), ('have', 'VBN'), ('absolutely', 'RB'), ('no', 'DT'), ('issue', 'NN'), ('with', 'IN'), ('it', 'PRP'), ('i', 'VBZ'), ('ve', 'RB'), ('have', 'VBP'), ('this', 'DT'), ('hair', 'NN'), ('dryer', 'NN'), ('for', 'IN'), ('almost', 'RB'), ('4', 'CD'), ('year', 'NN'), ('now', 'RB'), ('and', 'CC'), ('to', 'TO'), ('this', 'DT'), ('day', 'NN'), ('i', 'VBZ'), ('love', 'VBP'), ('it', 'PRP'), ('i', 'VBZ'), ('have', 'VBP'), ('dry', 'VBN'), ('frizzy', 'JJ'), ('hermione', 'NN'), ('granger', 'NN'), ('esqe', 'VBP'), ('hair', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('need', 'VBP'), ('something', 'NN'), ('that', 'WDT'), ('wouldn', 'VBZ'), ('t', 'JJ'), ('feel', 'NN'), ('like', 'IN'), ('i', 'JJ'), ('m', 'VBP'), ('fry', 'VBP'), ('it', 'PRP'), ('i', 'VBZ'), ('highly', 'RB'), ('highly', 'RB'), ('recommend', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('everyone', 'NN'), ('it', 'PRP'), ('come', 'VBZ'), ('with', 'IN'), ('a', 'DT'), ('diffuser', 'NN'), ('which', 'WDT'), ('i', 'VBZ'), ('only', 'RB'), ('use', 'VBP'), ('like', 'JJ'), ('once', 'RB'), ('or', 'CC'), ('twice', 'RB'), ('but', 'CC'), ('it', 'PRP'), ('s', 'VBD'), ('ok', 'JJ'), ('i', 'JJ'), ('m', 'NN'), ('gon', 'NN'), ('na', 'TO'), ('have', 'VB'), ('this', 'DT'), ('one', 'CD'), ('for', 'IN'), ('awhile', 'NN'), ('i', 'NN'), ('love', 'VBP'), ('the', 'DT'), ('sleek', 'JJ'), ('design', 'NN'), ('too', 'RB'), ('i', 'JJ'), ('don', 'VBP'), ('t', 'JJ'), ('see', 'VBP'), ('it', 'PRP'), ('become', 'VB'), ('outdated', ...

# %%
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

adjective_tags = ['JJ','JJR','JJS']

lemmatized_text = []

for word in POS_tag:
    if word[1] in adjective_tags:
        lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0],pos="a")))
    else:
        lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0]))) #default POS = noun
        
print ("Text tokens after lemmatization of adjectives and nouns: \n")
print (lemmatized_text)
# Out:
# Text tokens after lemmatization of adjectives and nouns:
#
# ['after', 'my', '60', 'salon', 'brand', 'hair', 'dryer', 'crap', 'out', 'on', 'me', 'after', 'like', '4', 'month', 'i', 'decide', 'to', 'just', 'look', 'for', 'a', 'hair', 'dryer', 'with', 'a', 'great', 'price', 'i', 'do', 'not', 'even', 'realize', 'that', 'it', 's', 'a', 'conditioning', 'dryer', 'and', 'now', 'my', 'hair', 'never', 'look', 'well', 'my', 'old', 'dryer', 'make', 'my', 'hair', 'look', 'dry', 'and', 'unhealthy', 'and', 'i', 'can', 't', 'believe', 'how', 'much', 'good', 'it', 'look', 'now', 'i', 'love', 'it', 'it', 'doesn', 't', 'get', 'super', 'hot', 'but', 'dry', 'my', 'long', 'thick', 'hair', 'fast', 'and', 'fluffy', 'i', 've', 'have', 'it', 'for', 'a', 'little', 'over', 'a', 'year', 'now', 'and', 'it', 'be', 'still', 'work', 'great', 'great', 'buy', 'love', 'this', 'dryer', 'i', 'specifically', 'choose', 'it', 'because', 'it', 'be', 'not', 'a', 'loud', 'a', 'others', 'we', 'be', 'look', 'for', 'a', 'good', 'quality', 'simple', 'hair', 'drier', 'this', 'one', 'seem', 'to', 'fit', 'the', 'bill', 'br', 'it', 'work', 'well', 'dry', 'hair', 'quickly', 'and', 'seem', 'to', 'help', 'tame', 'the', 'frizzies', 'we', 'have', 'be', 'use', 'it', 'for', 'quite', 'a', 'while', 'now', 'and', 'have', 'have', 'absolutely', 'no', 'issue', 'with', 'it', 'i', 've', 'have', 'this', 'hair', 'dryer', 'for', 'almost', '4', 'year', 'now', 'and', 'to', 'this', 'day', 'i', 'love', 'it', 'i', 'have', 'dry', 'frizzy', 'hermione', 'granger', 'esqe', 'hair', 'so', 'i', 'need', 'something', 'that', 'wouldn', 't', 'feel', 'like', 'i', 'm', 'fry', 'it', 'i', 'highly', 'highly', 'recommend', 'it', 'to', 'everyone', 'it', 'come', 'with', 'a', 'diffuser', 'which', 'i', 'only', 'use', 'like', 'once', 'or', 'twice', 'but', 'it', 's', 'ok', 'i', 'm', 'gon', 'na', 'have', 'this', 'one', 'for', 'awhile', 'i', 'love', 'the', 'sleek', 'design', 'too', 'i', 'don', 't', 'see', 'it', 'become', 'outdated', 'like', 'those', 'pink', 'and', 'green', 'hair', 'dryer', 'from', 'the', '70', 'or', 'something', 'thanks', 'scientist', 'at', 'conair', 'i', 'salute', 'you', 'good', 'bang', 'for', 'the', 'buck', 'work', 'fine', 'this', 'be', 'a', 'very', 'simple', 'but', 'great', 'blower', 'we', 'be', 'use', 'it', 'daily', 'and', 'be', 'happy', 'with', 'it', 'good', 'product', 'i', 'first', 'use', 'this', 'hair', 'dryer', 'in', 'a', 'hotel', 'after', 'that', 'i', 'have', 'to', 'have', 'one', 'i', 'find', 'it', 'on', 'amazon', 'make', 'the', 'purchase', 'and', 'i', 'be', 'very', 'pleased', 'with', 'my', 'purchase', 'best', 'price', 'i', 'have', 'see', 'plus', 'great', 'quality', 'super', 'quiet', 'not', 'a', 'giant', 'long', 'annoying', 'cord', 'not', 'too', 'short', 'of', 'a', 'cord', 'either', 'love', 'love', 'love', 'the', 'diffuser', 'attachment', 'since', 'i', 'have', 'curly', 'hair', 'attachment', 'stay', 'on', 'really', 'well', 'low', 'and', 'warm', 'do', 'a', 'great', 'job', 'on', 'my', 'thin', 'and', 'super', 'curly', 'hair', 'first', 'of', 'all', 'let', 's', 'put', 'thing', 'in', 'perspective', 'i', 'be', 'not', 'a', 'stylist', 'i', 'don', 't', 'use', 'a', 'blow', 'dryer', 'to', 'style', 'my', 'hair', 'but', 'rather', 'to', 'dry', 'it', 'after', 'shower', 'i', 'have', 'very', 'thin', 'fine', 'hair', 'that', 'dry', 'quickly', 'but', 'easily', 'get', 'frizzy', 'and', 'fly', 'away', 'the', 'hand', 'dryer', 'i', 've', 'have', 'for', 'over', '15', 'year', 'do', 'the', 'job', 'but', 'unless', 'i', 'use', 'a', 'leave', 'in', 'conditioner', 'before', 'dry', 'my', 'hair', 'would', 'often', 'end', 'up', 'look', 'like', 'shredded', 'wheat', 'not', 'attractive', 'br', 'br', 'so', 'when', 'it', 'come', 'time', 'to', 'buy', 'a', 'new', 'dryer', 'i', 'take', 'a', 'look', 'at', 'the', 'ionic', 'one', 'which', 'claim', 'to', 'leave', 'hair', 'soft', 'and', 'silky', 'instead', 'of', 'frizzy', 'and', 'fly', 'away', 'and', 'since', 'this', 'one', 'be', 'so', 'inexpensive', 'i', 'figure', 'i', 'd', 'give', 'it', 'a', 'try', 'br', 'br', 'well', 'it', 's', 'fabulous', 'when', 'dry',  ...

# %%
POS_tag = nltk.pos_tag(lemmatized_text)

print ("Lemmatized text with POS tags: \n")
print (POS_tag)
# Out:
# Lemmatized text with POS tags:
#
# [('after', 'IN'), ('my', 'PRP$'), ('60', 'CD'), ('salon', 'NN'), ('brand', 'NN'), ('hair', 'NN'), ('dryer', 'NN'), ('crap', 'NN'), ('out', 'IN'), ('on', 'IN'), ('me', 'PRP'), ('after', 'IN'), ('like', 'IN'), ('4', 'CD'), ('month', 'NN'), ('i', 'NN'), ('decide', 'VBP'), ('to', 'TO'), ('just', 'RB'), ('look', 'VB'), ('for', 'IN'), ('a', 'DT'), ('hair', 'NN'), ('dryer', 'NN'), ('with', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('price', 'NN'), ('i', 'NNS'), ('do', 'VBP'), ('not', 'RB'), ('even', 'RB'), ('realize', 'VB'), ('that', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('conditioning', 'NN'), ('dryer', 'NN'), ('and', 'CC'), ('now', 'RB'), ('my', 'PRP$'), ('hair', 'NN'), ('never', 'RB'), ('look', 'VBP'), ('well', 'RB'), ('my', 'PRP$'), ('old', 'JJ'), ('dryer', 'NN'), ('make', 'VB'), ('my', 'PRP$'), ('hair', 'NN'), ('look', 'VB'), ('dry', 'JJ'), ('and', 'CC'), ('unhealthy', 'JJ'), ('and', 'CC'), ('i', 'JJ'), ('can', 'MD'), ('t', 'VB'), ('believe', 'VB'), ('how', 'WRB'), ('much', 'JJ'), ('good', 'JJ'), ('it', 'PRP'), ('look', 'VBP'), ('now', 'RB'), ('i', 'RB'), ('love', 'VBP'), ('it', 'PRP'), ('it', 'PRP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('get', 'VB'), ('super', 'JJ'), ('hot', 'JJ'), ('but', 'CC'), ('dry', 'JJ'), ('my', 'PRP$'), ('long', 'JJ'), ('thick', 'JJ'), ('hair', 'NN'), ('fast', 'RB'), ('and', 'CC'), ('fluffy', 'VB'), ('i', 'NN'), ('ve', 'NNS'), ('have', 'VBP'), ('it', 'PRP'), ('for', 'IN'), ('a', 'DT'), ('little', 'JJ'), ('over', 'RP'), ('a', 'DT'), ('year', 'NN'), ('now', 'RB'), ('and', 'CC'), ('it', 'PRP'), ('be', 'VB'), ('still', 'RB'), ('work', 'VB'), ('great', 'JJ'), ('great', 'JJ'), ('buy', 'NN'), ('love', 'IN'), ('this', 'DT'), ('dryer', 'NN'), ('i', 'VBZ'), ('specifically', 'RB'), ('choose', 'VB'), ('it', 'PRP'), ('because', 'IN'), ('it', 'PRP'), ('be', 'VB'), ('not', 'RB'), ('a', 'DT'), ('loud', 'NN'), ('a', 'DT'), ('others', 'NNS'), ('we', 'PRP'), ('be', 'VB'), ('look', 'VBN'), ('for', 'IN'), ('a', 'DT'), ('good', 'JJ'), ('quality', 'NN'), ('simple', 'JJ'), ('hair', 'NN'), ('drier', 'RBR'), ('this', 'DT'), ('one', 'CD'), ('seem', 'NN'), ('to', 'TO'), ('fit', 'VB'), ('the', 'DT'), ('bill', 'NN'), ('br', 'VBZ'), ('it', 'PRP'), ('work', 'VB'), ('well', 'RB'), ('dry', 'JJ'), ('hair', 'NN'), ('quickly', 'RB'), ('and', 'CC'), ('seem', 'VB'), ('to', 'TO'), ('help', 'VB'), ('tame', 'VB'), ('the', 'DT'), ('frizzies', 'NNS'), ('we', 'PRP'), ('have', 'VBP'), ('be', 'VB'), ('use', 'VBP'), ('it', 'PRP'), ('for', 'IN'), ('quite', 'RB'), ('a', 'DT'), ('while', 'NN'), ('now', 'RB'), ('and', 'CC'), ('have', 'VBP'), ('have', 'VBN'), ('absolutely', 'RB'), ('no', 'DT'), ('issue', 'NN'), ('with', 'IN'), ('it', 'PRP'), ('i', 'VBZ'), ('ve', 'RB'), ('have', 'VBP'), ('this', 'DT'), ('hair', 'NN'), ('dryer', 'NN'), ('for', 'IN'), ('almost', 'RB'), ('4', 'CD'), ('year', 'NN'), ('now', 'RB'), ('and', 'CC'), ('to', 'TO'), ('this', 'DT'), ('day', 'NN'), ('i', 'VBZ'), ('love', 'VBP'), ('it', 'PRP'), ('i', 'VBZ'), ('have', 'VBP'), ('dry', 'VBN'), ('frizzy', 'JJ'), ('hermione', 'NN'), ('granger', 'NN'), ('esqe', 'VBP'), ('hair', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('need', 'VBP'), ('something', 'NN'), ('that', 'WDT'), ('wouldn', 'VBZ'), ('t', 'JJ'), ('feel', 'NN'), ('like', 'IN'), ('i', 'JJ'), ('m', 'VBP'), ('fry', 'VBP'), ('it', 'PRP'), ('i', 'VBZ'), ('highly', 'RB'), ('highly', 'RB'), ('recommend', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('everyone', 'NN'), ('it', 'PRP'), ('come', 'VBZ'), ('with', 'IN'), ('a', 'DT'), ('diffuser', 'NN'), ('which', 'WDT'), ('i', 'VBZ'), ('only', 'RB'), ('use', 'VBP'), ('like', 'JJ'), ('once', 'RB'), ('or', 'CC'), ('twice', 'RB'), ('but', 'CC'), ('it', 'PRP'), ('s', 'VBD'), ('ok', 'JJ'), ('i', 'JJ'), ('m', 'NN'), ('gon', 'NN'), ('na', 'TO'), ('have', 'VB'), ('this', 'DT'), ('one', 'CD'), ('for', 'IN'), ('awhile', 'NN'), ('i', 'NN'), ('love', 'VBP'), ('the', 'DT'), ('sleek', 'JJ'), ('design', 'NN'), ('too', 'RB'), ('i', 'JJ'), ('don', 'VBP'), ('t', 'JJ'), ('see', 'VBP'), ('it', 'PRP'), ('become', 'VB'), ('outdated', ' ...

# %%
stopwords = []

wanted_POS = ['NN','NNS','NNP','NNPS','JJ','JJR','JJS','VBG','FW'] 

for word in POS_tag:
    if word[1] not in wanted_POS:
        stopwords.append(word[0])

punctuations = list(str(string.punctuation))

stopwords = stopwords + punctuations

# %%
stopword_file = open("long_stopwords.txt", "r")
#Source = https://www.ranks.nl/stopwords

lots_of_stopwords = []

for line in stopword_file.readlines():
    lots_of_stopwords.append(str(line.strip()))

stopwords_plus = []
stopwords_plus = stopwords + lots_of_stopwords
stopwords_plus = set(stopwords_plus)

#Stopwords_plus contain total set of all stopwords

# %%
processed_text = []
for word in lemmatized_text:
    if word not in stopwords_plus:
        processed_text.append(word)
print (processed_text)
# Out:
# ['salon', 'brand', 'hair', 'crap', 'month', 'hair', 'great', 'price', 'conditioning', 'hair', 'hair', 'unhealthy', 'good', 'hair', 'year', 'great', 'great', 'loud', 'good', 'quality', 'simple', 'hair', 'bill', 'hair', 'frizzies', 'issue', 'hair', 'year', 'day', 'frizzy', 'hermione', 'granger', 'hair', 'diffuser', 'gon', 'awhile', 'sleek', 'design', 'outdated', 'pink', 'green', 'hair', 'conair', 'salute', 'good', 'bang', 'buck', 'fine', 'simple', 'great', 'blower', 'daily', 'happy', 'good', 'product', 'hair', 'hotel', 'purchase', 'pleased', 'purchase', 'best', 'price', 'great', 'quality', 'quiet', 'giant', 'annoying', 'cord', 'short', 'cord', 'diffuser', 'attachment', 'hair', 'attachment', 'stay', 'low', 'warm', 'great', 'job', 'thin', 'hair', 'thing', 'perspective', 'stylist', 'style', 'hair', 'shower', 'thin', 'fine', 'hair', 'frizzy', 'hand', 'year', 'job', 'conditioner', 'hair', 'shredded', 'wheat', 'attractive', 'time', 'ionic', 'claim', 'hair', 'soft', 'silky', 'frizzy', 'inexpensive', 'figure', 'fabulous', 'hair', 'silky', 'hair', 'silky', 'thing', 'silkiness', 'shampoos', 'complaint', 'blower', 'isn', 'strong', 'point', 'air', 'emit', 'conair', 'blower', 'strong', 'hair', 'amount', 'time', 'great', 'isn', 'heat', 'amount', 'air', 'ionic', 'thing', 'thing', 'fact', 'fifteen', 'year', 'ice', 'cake', 'great', 'good', 'noisy', 'strong', 'price', 'attractive', 'good', 'quality', 'price', 'light', 'heat', 'blowing', 'room', 'temperature', 'air', 'safe', 'hair', 'gf', 'price', 'good', 'dog', 'mild', 'setting', 'bath', 'bath', 'thing', 'associate', 'great', 'attachment', 'pic', 'heat', 'lot', 'thing', 'strong', 'good', 'deal', 'hair', 'perfect', 'pricing', 'thumb', 'low', 'price', 'big', 'bit', 'big', 'good', 'deal', 'guy', 'hair', 'minute', 'morning', 'shower', 'gemstone', 'coat', 'heat', 'element', 'salon', 'duty', 'roller', 'bearing', 'pink', 'gemstone', 'handle', 'air', 'front', 'switch', 'model', 'fine', 'bell', 'whistle', 'gee', 'gaws', 'bank', 'good', 'guy', 'color', 'cheap', 'fancy', 'job', 'great', 'temperature', 'attachment', 'good', 'sister', 'nice', 'quiet', 'isn', 'bad', 'high', 'pitch', 'hair', 'quiet', 'relative', 'attachment', 'easy', 'happy', 'price', 'hair', 'defuser', 'cooler', 'style', 'heat', 'price', 'great', 'top', 'quality', 'cord', 'short', 'normal', 'expense', 'hearing', 'hair', 'wife', 'burnt', 'electrical', 'smell', 'online', 'order', 'product', 'hair', 'quick', 'feature', 'low', 'price', 'pleased', 'concern', 'post', 'weight', 'fact', 'perfect', 'size', 'issue', 'brand', 'cord', 'cord', 'handle', 'cord', 'protect', 'time', 'hopeful', 'glad', 'purchase', 'option', 'lot', 'review', 'glad', 'great', 'compare', 'ive', 'ion', 'difference', 'ion', 'button', 'air', 'great', 'switch', 'air', 'hole', 'button', 'great', 'neck', 'daughter', 'neck', 'problem', 'girl', 'hair', 'cu', 'neck', 'hair', 'great', 'deal', 'problem', 'great', 'lot', 'time', 'time', 'hair', 'amount', 'time', 'easy', 'handle', 'option', 'expensive', 'add', 'ons', 'easy', 'couple', 'month', 'rough', 'bathroom', 'tucked', 'makeup', 'table', 'floor', 'cabnit', 'issue', 'scratch', 'si', 'mine', 'month', 'mom', 'sure', 'exact', 'store', 'confussing', 'exact', 'gift', 'hair', 'live', 'area', 'high', 'humidity', 'hair', 'money', 'attachment', 'interested', 'money', 'great', 'product', 'great', 'price', 'temperature', 'issue', 'purchase', 'excellent', 'job', 'problem', 'dokie', 'smoky', 'ionic', 'switch', 'reason', 'suppose', 'people', 'review', 'detail', 'write', 'price', 'good', 'quality', 'hair', 'comment', 'hair', 'heavy', 'light', 'family', 'year', 'hair', 'guest', 'usual', 'delivery', 'good', 'price', 'free', 'shipping', 'case', 'pleasure', 'dang', 'hairdryer', 'air', 'heating', 'element', 'air', 'evaporates', 'water', 'hair', 'science', 'ion', 'function', 'blast', 'button', 'extra', 'electron', 'hangin', 'negative', 'ion', 'slow', 'speed', 'fan', 'couple', 'diffuser', 'nice', 'safe', 'warmer', 'winter', 'foot', 'wife', 'hideous', 'shriekin ...

# %%
vocabulary = list(set(processed_text))
print (vocabulary)
# Out:
# ['diffuser', 'coat', 'loud', 'element', 'crap', 'daughter', 'winter', 'unhealthy', 'roller', 'area', 'phrase', 'noisy', 'function', 'pic', 'blower', 'big', 'cabnit', 'light', 'bed', 'touch', 'dog', 'previous', 'review', 'cu', 'box', 'emit', 'smoky', 'bad', 'room', 'bit', 'electron', 'ionic', 'figure', 'usable', 'quality', 'detail', 'stay', 'deal', 'speed', 'stylist', 'pink', 'pleasant', 'cake', 'girl', 'hair', 'relative', 'option', 'money', 'glad', 'slow', 'couldn', 'outdated', 'thumb', 'online', 'ice', 'smell', 'simple', 'normal', 'makeup', 'negative', 'fancy', 'temperature', 'hairdryer', 'water', 'gaws', 'morning', 'noise', 'body', 'complaint', 'thought', 'job', 'extra', 'hoot', 'bath', 'spot', 'practicable', 'bone', 'sure', 'silkiness', 'medium', 'arm', 'shrieking', 'stupid', 'remark', 'evaporates', 'silky', 'pleasure', 'good', 'si', 'shampoos', 'people', 'convinced', 'layer', 'salon', 'mine', 'wife', 'point', 'write', 'daily', 'quiet', 'claim', 'model', 'color', 'instance', 'coarser', 'order', 'head', 'sister', 'scratch', 'excellent', 'bang', 'strong', 'granger', 'bank', 'softer', 'gf', 'gon', 'button', 'ive', 'couple', 'air', 'heavy', 'hesitate', 'entire', 'issue', 'reason', 'pitch', 'quick', 'nozzle', 'perspective', 'neck', 'floor', 'bathroom', 'suppose', 'range', 'damage', 'gee', 'compare', 'sleek', 'cord', 'live', 'year', 'nice', 'burnt', 'moment', 'expense', 'family', 'finger', 'initial', 'shiney', 'guest', 'frizzy', 'time', 'bell', 'dokie', 'green', 'heat', 'fan', 'warmer', 'conditioning', 'purchase', 'annoying', 'protect', 'confussing', 'comment', 'ion', 'humidity', 'ons', 'min', 'happy', 'thin', 'mild', 'week', 'buck', 'shiny', 'rough', 'conair', 'dang', 'aspect', 'easy', 'tucked', 'post', 'hopeful', 'investment', 'hotel', 'awhile', 'expensive', 'product', 'defuser', 'decision', 'pricing', 'case', 'top', 'fifteen', 'gemstone', 'reviewer', 'usual', 'best', 'delivery', 'safe', 'minute', 'woman', 'month', 'gift', 'conditioner', 'salute', 'pleased', 'heating', 'setting', 'switch', 'cooler', 'humid', 'add', 'concern', 'thing', 'giant', 'gallon', 'shower', 'wheat', 'foot', 'frizzies', 'soft', 'cheap', 'table', 'interested', 'whistle', 'bill', 'fact', 'inexpensive', 'duty', 'guy', 'bonus', 'price', 'shot', 'shoulder', 'shipping', 'store', 'short', 'hole', 'dose', 'low', 'amount', 'lot', 'fabulous', 'weight', 'length', 'hideous', 'focus', 'blowing', 'hermione', 'design', 'feature', 'associate', 'day', 'exact', 'brand', 'milk', 'second', 'mom', 'problem', 'attachment', 'blast', 'great', 'front', 'wave', 'high', 'warm', 'hearing', 'difference', 'free', 'hand', 'perfect', 'style', 'handle', 'hangin', 'dead', 'isn', 'science', 'attractive', 'imagination', 'size', 'fine', 'shredded', 'electrical', 'bearing']

# %%
phrases = []

phrase = " "
for word in lemmatized_text:
    
    if word in stopwords_plus:
        if phrase!= " ":
            phrases.append(str(phrase).strip().split())
        phrase = " "
    elif word not in stopwords_plus:
        phrase+=str(word)
        phrase+=" "

print("Partitioned Phrases (Candidate Keyphrases): \n")
print(phrases)
# Out:
# Partitioned Phrases (Candidate Keyphrases):
#
# [['salon', 'brand', 'hair'], ['crap'], ['month'], ['hair'], ['great', 'price'], ['conditioning'], ['hair'], ['hair'], ['unhealthy'], ['good'], ['hair'], ['year'], ['great', 'great'], ['loud'], ['good', 'quality', 'simple', 'hair'], ['bill'], ['hair'], ['frizzies'], ['issue'], ['hair'], ['year'], ['day'], ['frizzy', 'hermione', 'granger'], ['hair'], ['diffuser'], ['gon'], ['awhile'], ['sleek', 'design'], ['outdated'], ['pink'], ['green', 'hair'], ['conair'], ['salute'], ['good', 'bang'], ['buck'], ['fine'], ['simple'], ['great', 'blower'], ['daily'], ['happy'], ['good', 'product'], ['hair'], ['hotel'], ['purchase'], ['pleased'], ['purchase', 'best', 'price'], ['great', 'quality'], ['quiet'], ['giant'], ['annoying', 'cord'], ['short'], ['cord'], ['diffuser', 'attachment'], ['hair', 'attachment', 'stay'], ['low'], ['warm'], ['great', 'job'], ['thin'], ['hair'], ['thing'], ['perspective'], ['stylist'], ['style'], ['hair'], ['shower'], ['thin', 'fine', 'hair'], ['frizzy'], ['hand'], ['year'], ['job'], ['conditioner'], ['hair'], ['shredded', 'wheat'], ['attractive'], ['time'], ['ionic'], ['claim'], ['hair', 'soft'], ['silky'], ['frizzy'], ['inexpensive'], ['figure'], ['fabulous'], ['hair'], ['silky'], ['hair'], ['silky'], ['thing'], ['silkiness'], ['shampoos'], ['complaint'], ['blower'], ['isn'], ['strong'], ['point'], ['air', 'emit'], ['conair'], ['blower'], ['strong'], ['hair'], ['amount'], ['time'], ['great', 'isn'], ['heat'], ['amount'], ['air'], ['ionic', 'thing'], ['thing'], ['fact'], ['fifteen', 'year'], ['ice'], ['cake'], ['great'], ['good'], ['noisy'], ['strong'], ['price'], ['attractive'], ['good', 'quality'], ['price', 'light'], ['heat'], ['blowing', 'room', 'temperature', 'air'], ['safe'], ['hair'], ['gf'], ['price'], ['good'], ['dog'], ['mild', 'setting'], ['bath'], ['bath'], ['thing', 'associate'], ['great'], ['attachment'], ['pic'], ['heat'], ['lot'], ['thing'], ['strong'], ['good', 'deal'], ['hair'], ['perfect'], ['pricing'], ['thumb'], ['low', 'price'], ['big'], ['bit'], ['big'], ['good', 'deal'], ['guy'], ['hair'], ['minute'], ['morning'], ['shower'], ['gemstone', 'coat', 'heat', 'element'], ['salon', 'duty', 'roller', 'bearing'], ['pink', 'gemstone'], ['handle'], ['air'], ['front'], ['switch'], ['model'], ['fine'], ['bell', 'whistle'], ['gee', 'gaws'], ['bank'], ['good', 'guy', 'color'], ['cheap'], ['fancy'], ['job'], ['great'], ['temperature'], ['attachment'], ['good'], ['sister'], ['nice'], ['quiet'], ['isn'], ['bad'], ['high', 'pitch'], ['hair'], ['quiet'], ['relative'], ['attachment'], ['easy'], ['happy'], ['price'], ['hair'], ['defuser'], ['cooler'], ['style'], ['heat'], ['price'], ['great'], ['top', 'quality'], ['cord'], ['short'], ['normal'], ['expense'], ['hearing'], ['hair'], ['wife'], ['burnt', 'electrical', 'smell'], ['online', 'order'], ['product'], ['hair'], ['quick'], ['feature'], ['low', 'price'], ['pleased'], ['concern'], ['post'], ['weight'], ['fact'], ['perfect', 'size'], ['issue'], ['brand'], ['cord'], ['cord'], ['handle'], ['cord'], ['protect'], ['time'], ['hopeful'], ['glad'], ['purchase'], ['option'], ['lot'], ['review'], ['glad'], ['great'], ['compare'], ['ive'], ['ion'], ['difference'], ['ion'], ['button'], ['air'], ['great'], ['switch'], ['air'], ['hole'], ['button'], ['great'], ['neck'], ['daughter', 'neck'], ['problem'], ['girl'], ['hair'], ['cu'], ['neck'], ['hair'], ['great', 'deal'], ['problem'], ['great'], ['lot'], ['time'], ['time'], ['hair'], ['amount'], ['time'], ['easy'], ['handle'], ['option'], ['expensive'], ['add', 'ons'], ['easy'], ['couple', 'month'], ['rough'], ['bathroom'], ['tucked'], ['makeup', 'table'], ['floor'], ['cabnit'], ['issue'], ['scratch'], ['si'], ['mine'], ['month'], ['mom'], ['sure'], ['exact'], ['store'], ['confussing'], ['exact'], ['gift'], ['hair'], ['live'], ['area'], ['high', 'humidity'], ['hair'], ['money'], ['attachment'], ['interested'], ['money', 'great', 'product'], ['great', 'price'], ['temperature'], ['issue'], ['purchase'], ['excellent', 'job'], ...

# %%
for word in vocabulary:
    #print word
    for phrase in phrases:
        if (word in phrase) and (len(phrase)>1):
            #if len(phrase)>1 then the current phrase is multi-worded.
            #if the word in vocabulary is present in unique_phrases as a single-word-phrase
            # and at the same time present as a word within a multi-worded phrase,
            # then I will remove the single-word-phrase from the list.
            phrases.remove([word])
            
print(phrases)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-6f5258c71ad0> in <module>
#       7             # and at the same time present as a word within a multi-worded phrase,
#       8             # then I will remove the single-word-phrase from the list.
# ----> 9             phrases.remove(word)
#      10
#      11 print(phrases)
#
# ValueError: list.remove(x): x not in list
